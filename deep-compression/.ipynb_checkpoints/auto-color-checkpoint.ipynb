# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from keras import backend as K
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Input, BatchNormalization, LeakyReLU
from keras.layers.merge import concatenate
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
# from tensorflow import set_random_seed
import tensorflow as tf
from skimage.io import imread
from PIL import Image
from skimage.transform import resize
from tensorflow.keras.applications.vgg16 import VGG16
from keras.layers import *

# %%
face_scrub_actors_data = os.path.join('data/faceScrub', 'facescrub_actors.txt')
face_scrub_actress_data = os.path.join(
    'data/faceScrub', 'facescrub_actresses.txt')
data_path = '/Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/HandWriting Detection/bounding-box-predictions/data'
actors_dir = os.path.join(data_path, 'actors')
actress_dir = os.path.join(data_path, 'actress')
images_path = ''

# %%
def load_image(path):
    return imread(path)

# %%
def read_image(path):
    img = Image.open(path).convert('RGB')
    return img
    #return np.asarray(img) YCbCr

# %%
def display_image(image):
    fig = plt.figure
    plt.imshow(image, cmap='brg')

# %%
def display_ycbcr_image(image):
    fig = plt.figure
    plt.imshow(image, cmap='YCbCr')

# %%
def get_all_files(path):
    onlyfiles = [f for f in os.listdir(
        path) if os.path.isfile(os.path.join(path, f))]
    return onlyfiles

# %%
actor_image_paths = get_all_files(actors_dir) 
actress_image_paths = get_all_files(actress_dir)

# %%
for x in range(len(actor_image_paths)):
    actor_image_paths[x] = os.path.join(actors_dir, actor_image_paths[x])
for x in range(len(actress_image_paths)):
    actress_image_paths[x] = os.path.join(actress_dir, actress_image_paths[x])

# %%
image_paths = [None]* len(actor_image_paths) + len(actress_image_paths)

# %%
image_paths = [actor_image_paths, actress_image_paths]

# %%
image_paths = [item for sublist in image_paths for item in sublist]

# %%
#get all the image path.
path = '/Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/deep-compression/data/pics'
image_paths = get_all_files(
    path)
for x in range(len(image_paths)):
    image_paths[x] = os.path.join(path, image_paths[x])

# %%
#read all the images on the disk as rgb
images = []
for x in range(len(image_paths)):
    try:
       images.append(read_image(image_paths[x]))
    except:
       pass

# %%
display_image(images[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000029?line=0'>1</a> display_image(images[0])
#
# NameError: name 'display_image' is not defined

# %%
#Convert all images to gray-scale
def convert_to_gray_scale(image):
    image = np.array(image, np.uint8)
    return cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
def get_new_image_dimen(image, new_dimen):
    width = image.width
    height = image.height
    new_width = 0
    new_height = 0
    aspect_ratio = width / height
    if width > height:
        new_width = new_dimen
        new_height = new_dimen / aspect_ratio
    else:
        new_height = new_dimen
        new_width = new_dimen * aspect_ratio
    return (new_width, new_height)

# %%
def pad_image(image, max_size):
    old_image_height, old_image_width, channels = image.shape
    # create new image of desired size and color (blue) for padding
    new_image_width = max_size
    new_image_height = max_size
    color = (0, 0, 0)
    result = np.full((new_image_height, new_image_width,
                      channels), color, dtype=np.uint8)
    # compute center offset
    x_center = (new_image_width - old_image_width) // 2
    y_center = (new_image_height - old_image_height) // 2
    # print(image)
    # copy img image into center of result image
    # result[y_center:y_center+old_image_height,x_center:x_center+old_image_width] = image
    result[0:old_image_height, 0:old_image_width] = image
    return result

# %%
# resize the image. The aspect ratio of the image is maintained.
for x in range(len(images)):
    new_dimen = 240;
    new_width, new_height = get_new_image_dimen(images[x], new_dimen)
    images[x] = images[x].resize((int(new_width), int(new_height))) #resize(images[x], new_width, new_height)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb Cell 19' in <module>
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000014?line=1'>2</a> for x in range(len(images)):
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000014?line=2'>3</a>     new_dimen = 240;
# ----> <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000014?line=3'>4</a>     new_width, new_height = get_new_image_dimen(images[x], new_dimen)
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000014?line=4'>5</a>     images[x] = images[x].resize((int(new_width), int(new_height)))
#
# /Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb Cell 17' in get_new_image_dimen(image, new_dimen)
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000011?line=0'>1</a> def get_new_image_dimen(image, new_dimen):
# ----> <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000011?line=1'>2</a>     width = image.width
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000011?line=2'>3</a>     height = image.height
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000011?line=3'>4</a>     new_width = 0
#
# AttributeError: 'numpy.ndarray' object has no attribute 'width'

# %%
# display resized image
display_image(images[0])

# %%
#images are converted to numpy arrays to be padded.
for x in range(len(images)):
    images[x] = np.asarray(images[x])

# %%
# display resized image
display_image(images[0])

# %%
images[x]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py:1229, in _save(im, fp, filename, chunk, save_all)
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py?line=1227'>1228</a> try:
# -> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py?line=1228'>1229</a>     rawmode, mode = _OUTMODES[mode]
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py?line=1229'>1230</a> except KeyError as e:
#
# KeyError: 'YCbCr'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py:652, in Image._repr_png_(self)
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=650'>651</a> try:
# --> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=651'>652</a>     self.save(b, "PNG")
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=652'>653</a> except Exception as e:
#
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py:2212, in Image.save(self, fp, format, **params)
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=2210'>2211</a> try:
# -> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=2211'>2212</a>     save_handler(self, fp, filename)
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=2212'>2213</a> finally:
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=2213'>2214</a>     # do what we can to clean up
#
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py:1231, in _save(im, fp, filename, chunk, save_all)
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py?line=1229'>1230</a> except KeyError as e:
# -> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py?line=1230'>1231</a>     raise OSError(f"cannot write mode {mode} as PNG") from e
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py?line=1232'>1233</a> #
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/PngImagePlugin.py?line=1233'>1234</a> # write minimal PNG file
#
# OSError: cannot write mode YCbCr as PNG
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/IPython/core/formatters.py?line=340'>341</a>     method = get_real_method(obj, self.print_method)
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/IPython/core/formatters.py?line=341'>342</a>     if method is not None:
# --> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/IPython/core/formatters.py?line=342'>343</a>         return method()
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/IPython/core/formatters.py?line=343'>344</a>     return None
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/IPython/core/formatters.py?line=344'>345</a> else:
#
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py:654, in Image._repr_png_(self)
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=651'>652</a>     self.save(b, "PNG")
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=652'>653</a> except Exception as e:
# --> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=653'>654</a>     raise ValueError("Could not save to PNG for display") from e
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=654'>655</a> return b.getvalue()
#
# ValueError: Could not save to PNG for display
# <PIL.Image.Image image mode=YCbCr size=240x240 at 0x7FD651DF3E80>

# %%
# since the images do not have the same aspect ratios,
# the image is padded to have the same aspect ratios. 
for x in range(len(images)):
    images[x] = pad_image(images[x], 240)

# %%
# display padded image
display_image(images[0])

# %%
def convert_np_rgb_image_to_ycbcr(image):
    return Image.fromarray(image).convert('YCbCr')

# %%
def get_y_channel_from_ycbcr(ycbcr_image):
    return np.asarray(ycbcr_image.getchannel('Y'))

# %%
def get_cbcr_channel_from_ycbcr(ycbcr_image: Image):
    (y, cb, cr) = ycbcr_image.split()
    return np.asarray(Image.merge('CbCr', (cb, cr)))

# %%
# rgb np array is converted ycbcr color space
for x in range(len(images)):
    images[x] = convert_np_rgb_image_to_ycbcr(images[x])

# %%
# display ycbcr image
display_image(images[0])

# %%
images_y_channel = [None] * len(images)
# y channel is extracted from the ycbcr color space
for x in range(len(images)):
    images_y_channel[x] = get_y_channel_from_ycbcr(images[x])

# %%
images_cb_cr_channel = [None] * len(images)
for x in range(len(images)):
    images_y_channel[x] = get_cbcr_channel_from_ycbcr(images[x])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb Cell 33' in <module>
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000051?line=0'>1</a> images_cb_cr_channel = [None] * len(images)
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000051?line=1'>2</a> for x in range(len(images)):
# ----> <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000051?line=2'>3</a>     images_y_channel[x] = get_cbcr_channel_from_ycbcr(images[x])
#
# /Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb Cell 29' in get_cbcr_channel_from_ycbcr(ycbcr_image)
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000052?line=0'>1</a> def get_cbcr_channel_from_ycbcr(ycbcr_image: Image):
#       <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000052?line=1'>2</a>     (y, cb, cr) = ycbcr_image.split()
# ----> <a href='vscode-notebook-cell:/Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/deep-compression/auto-color.ipynb#ch0000052?line=2'>3</a>     return np.asarray(Image.merge('CbCr', (cb, cr)))
#
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py:3100, in merge(mode, bands)
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3087'>3088</a> def merge(mode, bands):
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3088'>3089</a>     """
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3089'>3090</a>     Merge a set of single band images into a new multiband image.
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3090'>3091</a>
#    (...)
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3096'>3097</a>     :returns: An :py:class:`~PIL.Image.Image` object.
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3097'>3098</a>     """
# -> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3099'>3100</a>     if getmodebands(mode) != len(bands) or "*" in mode:
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3100'>3101</a>         raise ValueError("wrong number of bands")
#    <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=3101'>3102</a>     for band in bands[1:]:
#
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py:305, in getmodebands(mode)
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=296'>297</a> def getmodebands(mode):
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=297'>298</a>     """
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=298'>299</a>     Gets the number of individual bands for this mode.
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=299'>300</a>
#    (...)
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=302'>303</a>     :exception KeyError: If the input mode was not a standard mode.
#     <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=303'>304</a>     """
# --> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/Image.py?line=304'>305</a>     return len(ImageMode.getmode(mode).bands)
#
# File ~/Documents/Pycharm Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/ImageMode.py:74, in getmode(mode)
#      <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/ImageMode.py?line=71'>72</a>     # set global mode cache atomically
#      <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/ImageMode.py?line=72'>73</a>     _modes = modes
# ---> <a href='file:///Users/ernestopoku-kwarteng/Documents/Pycharm%20Projects/Anaconda/Machine-Learning/ml-env/lib/python3.8/site-packages/PIL/ImageMode.py?line=73'>74</a> return _modes[mode]
#
# KeyError: 'CbCr'

# %%
for x in range(len(images)):
    images[x] = np.asarray(images[x])

# %%
images = np.array((images))
images_y_channel = np.array(images_y_channel)

# %%
images[0]
# Out:
# array([[[178, 130, 125],
#         [178, 130, 125],
#         [178, 130, 125],
#         ...,
#         [142, 130, 125],
#         [151, 131, 125],
#         [158, 131, 126]],
#
#        [[178, 130, 125],
#         [178, 130, 125],
#         [178, 130, 125],
#         ...,
#         [142, 130, 125],
#         [151, 131, 125],
#         [158, 131, 126]],
#
#        [[175, 130, 125],
#         [175, 130, 125],
#         [174, 130, 125],
#         ...,
#         [143, 130, 125],
#         [152, 131, 125],
#         [159, 131, 126]],
#
#        ...,
#
#        [[  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128],
#         ...,
#         [  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128]],
#
#        [[  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128],
#         ...,
#         [  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128]],
#
#        [[  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128],
#         ...,
#         [  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128]]], dtype=uint8)

# %%
images_y_channel[0][0][0]
# Out:
# 178

# %%
images = images / 255
images_y_channel  = images_y_channel / 255

# %%
## Loading VGG16 model
base_model = VGG16(weights="imagenet", include_top=False,
                   input_shape=(96, 96, 3), input_tensor=Input(shape=(150, 150, 3)))
base_model.trainable = False  # Not trainable weights
base_model.summary()

# %%
#Encoder
encoder_input = Input(shape=(240, 240, 1,))
encoder_output = Conv2D(64, (3, 3), activation='relu',
                        padding='same', strides=2)(encoder_input)
encoder_output = Conv2D(128, (3, 3), activation='relu',
                        padding='same')(encoder_output)
encoder_output = Conv2D(128, (3, 3), activation='relu',
                        padding='same', strides=2)(encoder_output)
encoder_output = Conv2D(256, (3, 3), activation='relu',
                        padding='same')(encoder_output)
encoder_output = Conv2D(256, (3, 3), activation='relu',
                        padding='same', strides=2)(encoder_output)
encoder_output = Conv2D(512, (3, 3), activation='relu',
                        padding='same')(encoder_output)
encoder_output = Conv2D(512, (3, 3), activation='relu',
                        padding='same')(encoder_output)
encoder_output = Conv2D(256, (3, 3), activation='relu',
                        padding='same')(encoder_output)

img_size_target = 240
img_input = Input(shape=(img_size_target, img_size_target, 1))
img_conc = Concatenate()([img_input, img_input, img_input])
base_model = VGG16(input_tensor=img_conc)
base_model.trainable = False  # Not trainable weights
# base_model.summary()
## Loading VGG16 model
# base_model = VGG16(weights="imagenet", include_top=False,
#                    input_shape=(240, 240, 1,))
# base_model.trainable = False  # Not trainable weights

last_layer = base_model.get_layer('block5_conv3').output
#Decoder

decoder_output = Conv2D(128, (3, 3), activation='relu',
                        padding='same')(last_layer)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(64, (3, 3), activation='relu',
                        padding='same')(decoder_output)
decoder_output = UpSampling2D((2, 2))(decoder_output)
decoder_output = Conv2D(32, (3, 3), activation='relu',
                        padding='same')(decoder_output)
decoder_output = Conv2D(16, (3, 3), activation='relu',
                        padding='same')(decoder_output)
decoder_output = Conv2D(3, (3, 3), activation='sigmoid',
                        padding='same')(decoder_output)
decoder_output = UpSampling2D((4, 4))(decoder_output)
model = Model(inputs=base_model.input, outputs=decoder_output)
model.summary();
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_37 (InputLayer)          [(None, 240, 240, 1  0           []
#                                 )]
#
#  concatenate_6 (Concatenate)    (None, 240, 240, 3)  0           ['input_37[0][0]',
#                                                                   'input_37[0][0]',
#                                                                   'input_37[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 240, 240, 64  1792        ['concatenate_6[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 240, 240, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 120, 120, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 120, 120, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 120, 120, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 60, 60, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 60, 60, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 60, 60, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 60, 60, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 30, 30, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 30, 30, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 30, 30, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 30, 30, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 15, 15, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 15, 15, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 15, 15, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 15, 15, 512)  2359808     ['block5_conv2[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 15, 15, 128)  589952      ['block5_conv3[0][0]']
#
#  up_sampling2d_21 (UpSampling2D  (None, 30, 30, 128)  0          ['conv2d_213[0][0]']
#  )
#
#  conv2d_214 (Conv2D)            (None, 30, 30, 64)   73792       ['up_sampling2d_21[0][0]']
#
#  up_sampling2d_22 (UpSampling2D  (None, 60, 60, 64)  0           ['conv2d_214[0][0]']
#  )
#
#  conv2d_215 (Conv2D)            (None, 60, 60, 32)   18464       ['up_sampling2d_22[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 60, 60, 16)   4624        ['conv2d_215[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 60, 60, 3)    435         ['conv2d_216[0][0]']
#
#  up_sampling2d_23 (UpSampling2D  (None, 240, 240, 3)  0          ['conv2d_217[0][0]']
#  )
#
# ==================================================================================================
# Total params: 15,401,955
# Trainable params: 687,267
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %%
im = images[0]
te = im[0, :, :]
te
# Out:
# array([[0.69803922, 0.50980392, 0.49019608],
#        [0.69803922, 0.50980392, 0.49019608],
#        [0.69803922, 0.50980392, 0.49019608],
#        [0.69411765, 0.50980392, 0.49803922],
#        [0.69411765, 0.50980392, 0.49803922],
#        [0.69411765, 0.50980392, 0.49803922],
#        [0.69411765, 0.50980392, 0.49803922],
#        [0.69411765, 0.50980392, 0.49803922],
#        [0.69019608, 0.50980392, 0.50196078],
#        [0.68627451, 0.50980392, 0.50196078],
#        [0.68627451, 0.50980392, 0.50196078],
#        [0.69019608, 0.50980392, 0.49803922],
#        [0.68627451, 0.50980392, 0.49411765],
#        [0.67843137, 0.50980392, 0.49019608],
#        [0.67843137, 0.50980392, 0.49019608],
#        [0.68235294, 0.50980392, 0.49803922],
#        [0.68235294, 0.50980392, 0.49803922],
#        [0.6745098 , 0.50980392, 0.49803922],
#        [0.6745098 , 0.50980392, 0.50196078],
#        [0.67058824, 0.50980392, 0.50196078],
#        [0.67058824, 0.50980392, 0.50196078],
#        [0.67843137, 0.50980392, 0.50196078],
#        [0.6745098 , 0.50980392, 0.50196078],
#        [0.6627451 , 0.50980392, 0.50196078],
#        [0.65882353, 0.50980392, 0.49803922],
#        [0.65490196, 0.50980392, 0.49803922],
#        [0.65490196, 0.50980392, 0.49803922],
#        [0.64313725, 0.50980392, 0.49803922],
#        [0.59215686, 0.50588235, 0.49803922],
#        [0.53333333, 0.50588235, 0.49803922],
#        [0.50588235, 0.49803922, 0.49803922],
#        [0.4745098 , 0.49803922, 0.49803922],
#        [0.44705882, 0.49803922, 0.49803922],
#        [0.42352941, 0.49411765, 0.49803922],
#        [0.4       , 0.49803922, 0.49803922],
#        [0.38039216, 0.49019608, 0.49803922],
#        [0.38431373, 0.48627451, 0.51372549],
#        [0.41176471, 0.48627451, 0.51764706],
#        [0.44313725, 0.48627451, 0.51764706],
#        [0.4627451 , 0.48627451, 0.52156863],
#        [0.48235294, 0.48627451, 0.52156863],
#        [0.49411765, 0.48627451, 0.52156863],
#        [0.49803922, 0.48627451, 0.5254902 ],
#        [0.51372549, 0.48235294, 0.5254902 ],
#        [0.52156863, 0.48627451, 0.52941176],
#        [0.5254902 , 0.48627451, 0.52941176],
#        [0.54117647, 0.48627451, 0.52941176],
#        [0.55294118, 0.48627451, 0.52941176],
#        [0.55686275, 0.48235294, 0.52156863],
#        [0.54509804, 0.48235294, 0.52156863],
#        [0.53333333, 0.48235294, 0.52156863],
#        [0.53333333, 0.48235294, 0.52156863],
#        [0.54117647, 0.48235294, 0.52156863],
#        [0.54901961, 0.48235294, 0.52156863],
#        [0.51372549, 0.51372549, 0.49411765],
#        [0.51764706, 0.50980392, 0.49803922],
#        [0.5254902 , 0.51372549, 0.49019608],
#        [0.54509804, 0.50980392, 0.48627451],
#        [0.51764706, 0.51372549, 0.48235294],
#        [0.45098039, 0.50980392, 0.47843137],
#        [0.36078431, 0.50980392, 0.47843137],
#        [0.34117647, 0.50980392, 0.47843137],
#        [0.34117647, 0.50980392, 0.47843137],
#        [0.34117647, 0.51372549, 0.48235294],
#        [0.33333333, 0.51372549, 0.48627451],
#        [0.34117647, 0.50980392, 0.49019608],
#        [0.3372549 , 0.50980392, 0.49019608],
#        [0.3372549 , 0.50980392, 0.49019608],
#        [0.34117647, 0.50980392, 0.49019608],
#        [0.34117647, 0.50980392, 0.49019608],
#        [0.34509804, 0.50980392, 0.49019608],
#        [0.34509804, 0.50980392, 0.49019608],
#        [0.34901961, 0.50980392, 0.49019608],
#        [0.35686275, 0.50980392, 0.49019608],
#        [0.36078431, 0.50980392, 0.49019608],
#        [0.36470588, 0.50980392, 0.49019608],
#        [0.37254902, 0.50980392, 0.49019608],
#        [0.37254902, 0.50980392, 0.49019608],
#        [0.37254902, 0.51372549, 0.49411765],
#        [0.38039216, 0.51372549, 0.49411765],
#        [0.38823529, 0.50980392, 0.49019608],
#        [0.39215686, 0.50980392, 0.48235294],
#        [0.39215686, 0.51372549, 0.48235294],
#        [0.39215686, 0.50980392, 0.47843137],
#        [0.40392157, 0.50980392, 0.47843137],
#        [0.45882353, 0.50980392, 0.48235294],
#        [0.51764706, 0.50980392, 0.48235294],
#        [0.55686275, 0.50980392, 0.49019608],
#        [0.59215686, 0.51372549, 0.49019608],
#        [0.61960784, 0.51372549, 0.49411765]])

# %%
new_im = [None] * im.shape[0]
for r in range(im.shape[0]):
    row = im[r]
    new_row = [None] * row.shape[0]
    for p in range(row.shape[0]):
        new_row[p] = [row[p][1], row[p][2]]
    new_im[r] = new_row

# %%
def get_y_channel(image):
    return image[:, :, 0]

# %%
def get_cbcr_channel(image):
    new_im = [None] * image.shape[0]
    for r in range(image.shape[0]):
        row = image[r]
        new_row = [None] * row.shape[0]
        for p in range(row.shape[0]):
            new_row[p] = [row[p][1], row[p][2]]
        new_im[r] = new_row
    return np.array(new_im)

# %%
get_cbcr_channel(images[0])
# Out:
# array([[[0.50980392, 0.49019608],
#         [0.50980392, 0.49019608],
#         [0.50980392, 0.49019608],
#         ...,
#         [0.50980392, 0.49019608],
#         [0.51372549, 0.49019608],
#         [0.51372549, 0.49411765]],
#
#        [[0.50980392, 0.49019608],
#         [0.50980392, 0.49019608],
#         [0.50980392, 0.49019608],
#         ...,
#         [0.50980392, 0.49019608],
#         [0.51372549, 0.49019608],
#         [0.51372549, 0.49411765]],
#
#        [[0.50980392, 0.49019608],
#         [0.50980392, 0.49019608],
#         [0.50980392, 0.49019608],
#         ...,
#         [0.50980392, 0.49019608],
#         [0.51372549, 0.49019608],
#         [0.51372549, 0.49411765]],
#
#        ...,
#
#        [[0.50196078, 0.50196078],

#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         ...,
#
#         [[0.05490196, 0.49803922, 0.50980392],
#          [0.05490196, 0.49803922, 0.51764706],
#          [0.05490196, 0.49803922, 0.51372549],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         [[0.04705882, 0.49803922, 0.51372549],
#          [0.05882353, 0.49803922, 0.51764706],
#          [0.05882353, 0.49803922, 0.50588235],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         [[0.05098039, 0.49411765, 0.50980392],
#          [0.0627451 , 0.49803922, 0.51764706],
#          [0.05882353, 0.50196078, 0.51372549],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]]],
#
#
#        [[[0.01176471, 0.50196078, 0.50196078],
#          [0.00784314, 0.50196078, 0.50196078],
#          [0.00392157, 0.50196078, 0.50196078],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         [[0.01176471, 0.50196078, 0.50196078],
#          [0.00784314, 0.50196078, 0.50196078],
#          [0.00392157, 0.50196078, 0.50196078],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         [[0.00784314, 0.50196078, 0.50196078],
#          [0.00784314, 0.50196078, 0.50196078],
#          [0.00784314, 0.50196078, 0.50196078],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         ...,
#
#         [[0.07843137, 0.50196078, 0.50196078],
#          [0.10196078, 0.50196078, 0.50196078],
#          [0.11372549, 0.50196078, 0.50196078],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         [[0.08235294, 0.50196078, 0.50196078],
#          [0.09411765, 0.50196078, 0.50196078],
#          [0.09411765, 0.50196078, 0.50196078],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]],
#
#         [[0.0745098 , 0.50196078, 0.50196078],
#          [0.08235294, 0.50196078, 0.50196078],
#          [0.07843137, 0.50196078, 0.50196078],
#          ...,
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078],
#          [0.        , 0.50196078, 0.50196078]]]])

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
model.fit(images_y_channel, images,
          validation_split=0.1, epochs=100)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 286s 4s/step - loss: 0.0189 - accuracy: 0.5038 - val_loss: 0.0138 - val_accuracy: 0.6195
# Epoch 2/100
# 80/80 [==============================] - 5760s 73s/step - loss: 0.0131 - accuracy: 0.5577 - val_loss: 0.0128 - val_accuracy: 0.5676
# Epoch 3/100
# 80/80 [==============================] - 314s 4s/step - loss: 0.0115 - accuracy: 0.5673 - val_loss: 0.0123 - val_accuracy: 0.5402
# Epoch 4/100
# 80/80 [==============================] - 378s 5s/step - loss: 0.0105 - accuracy: 0.5784 - val_loss: 0.0112 - val_accuracy: 0.5262
# Epoch 5/100
# 80/80 [==============================] - 396s 5s/step - loss: 0.0101 - accuracy: 0.5781 - val_loss: 0.0110 - val_accuracy: 0.7055
# Epoch 6/100
# 80/80 [==============================] - 393s 5s/step - loss: 0.0095 - accuracy: 0.5842 - val_loss: 0.0111 - val_accuracy: 0.7090
# Epoch 7/100
# 80/80 [==============================] - 393s 5s/step - loss: 0.0093 - accuracy: 0.5862 - val_loss: 0.0111 - val_accuracy: 0.6325
# Epoch 8/100
# 80/80 [==============================] - 390s 5s/step - loss: 0.0089 - accuracy: 0.5924 - val_loss: 0.0107 - val_accuracy: 0.4964
# Epoch 9/100
# 80/80 [==============================] - 396s 5s/step - loss: 0.0085 - accuracy: 0.5931 - val_loss: 0.0111 - val_accuracy: 0.5698
# Epoch 10/100
# 80/80 [==============================] - 396s 5s/step - loss: 0.0084 - accuracy: 0.5961 - val_loss: 0.0111 - val_accuracy: 0.5411
# Epoch 11/100
# 80/80 [==============================] - 430s 5s/step - loss: 0.0081 - accuracy: 0.6000 - val_loss: 0.0105 - val_accuracy: 0.5775
# Epoch 12/100
# 80/80 [==============================] - 421s 5s/step - loss: 0.0078 - accuracy: 0.5995 - val_loss: 0.0107 - val_accuracy: 0.7123
# Epoch 92/100
# 80/80 [==============================] - 302s 4s/step - loss: 0.0046 - accuracy: 0.6367 - val_loss: 0.0110 - val_accuracy: 0.4997
# Epoch 93/100
# 80/80 [==============================] - 301s 4s/step - loss: 0.0046 - accuracy: 0.6416 - val_loss: 0.0111 - val_accuracy: 0.5104
# Epoch 94/100
# 80/80 [==============================] - 302s 4s/step - loss: 0.0045 - accuracy: 0.6396 - val_loss: 0.0110 - val_accuracy: 0.6160
# Epoch 95/100
# 80/80 [==============================] - 301s 4s/step - loss: 0.0045 - accuracy: 0.6402 - val_loss: 0.0111 - val_accuracy: 0.5265
# Epoch 96/100
# 80/80 [==============================] - 300s 4s/step - loss: 0.0046 - accuracy: 0.6387 - val_loss: 0.0110 - val_accuracy: 0.5014
# Epoch 97/100
# 80/80 [==============================] - 302s 4s/step - loss: 0.0046 - accuracy: 0.6375 - val_loss: 0.0111 - val_accuracy: 0.4745
# Epoch 98/100
# 80/80 [==============================] - 303s 4s/step - loss: 0.0047 - accuracy: 0.6377 - val_loss: 0.0109 - val_accuracy: 0.5133
# Epoch 99/100
# 80/80 [==============================] - 301s 4s/step - loss: 0.0046 - accuracy: 0.6369 - val_loss: 0.0110 - val_accuracy: 0.6656
# Epoch 100/100
# 80/80 [==============================] - 298s 4s/step - loss: 0.0045 - accuracy: 0.6406 - val_loss: 0.0112 - val_accuracy: 0.6677

# %%
output = model.predict(np.array([images_y_channel[900]]))

# %%
def ycbcr2rgb(im):
    xform = np.array([[1, 0, 1.402], [1, -0.34414, -.71414], [1, 1.772, 0]])
    rgb = im.astype(np.float)
    rgb[:, :, [1, 2]] -= 128
    rgb = rgb.dot(xform.T)
    np.putmask(rgb, rgb > 255, 255)
    np.putmask(rgb, rgb < 0, 0)
    return np.uint8(rgb)

# %%
image = output[0] * 255
rgb_image =ycbcr2rgb(image)
# Out:
# /var/folders/kh/ldlc522d21lbvxg7zwz8yh8r0000gn/T/ipykernel_67439/1384511715.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rgb = im.astype(np.float)

# %%
# image = output[0][0] * 255
display_image(rgb_image)

# %%
#test image
test_image = read_image(
    '/Users/ernestopoku-kwarteng/Documents/Pycharm Projects/Anaconda/Machine-Learning/deep-compression/data/obaa2.jpg')

# %%
display_image(test_image)

# %%
# resize image
new_width, new_height = get_new_image_dimen(test_image, new_dimen)
test_image = test_image.resize((int(new_width), int(new_height)))

# %%
display_image(test_image)

# %%
test_image = np.asarray(test_image)

# %%
# pad image
test_image = pad_image(test_image, 240)

# %%
display_image(test_image)

# %%
# rgb np array is converted ycbcr color space
test_image = convert_np_rgb_image_to_ycbcr(test_image)

# %%
test_image = get_y_channel_from_ycbcr(test_image)

# %%
test_image.shape
# Out:
# (240, 240)

# %%
test_image = test_image / 255

# %%
output = model.predict(np.array([test_image]))

# %%
test_image = output[0] * 255
rgb_image = ycbcr2rgb(test_image)
# Out:
# /var/folders/kh/ldlc522d21lbvxg7zwz8yh8r0000gn/T/ipykernel_67439/1384511715.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rgb = im.astype(np.float)

# %%
display_image(rgb_image)
